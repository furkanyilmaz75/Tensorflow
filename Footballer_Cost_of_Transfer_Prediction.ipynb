# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame= pd.read_excel("footballer.xlsx")

# %%
dataFrame.head(10)
# Out:
#    AGE  AVERAGE PLACE NATION  PRICE  STAR  PASS  PACE  DOUBLE_PLACE  EDUCABLE  \
# 0   21       94    AM    FRA   88.0     1    90    96             1         1
# 1   35       93    RW    POR   65.0     1    97    97             1         1
# 2   27       90    RW    POR   65.0     1    91    97             0         0
# 3   20       89    CM    FRA   93.0     1    98    97             1         1
# 4   19       91    LW    GER  110.0     1    95    95             1         1
# 5   19       89    LW    SPA  110.0     1    92    93             1         1
# 6   23       88    LB    FRA   65.0     1    90    90             0         0
# 7   31       88    CF    FRA   33.0     1    83    83             0         1
# 8   31       88    CF    FRA   33.0     1    83    83             0         1
# 9   33       88    RB    GER   16.0     1    65    85             0         0
#
#    AGGRESSIVE
# 0           7
# 1           8
# 2           6
# 3           6
# 4           5
# 5           5
# ...

# %%
dataFrame.describe()
# Out:
#               AGE     AVERAGE       PRICE        STAR        PASS        PACE  \
# count  299.000000  299.000000  299.000000  299.000000  299.000000  299.000000
# mean    25.220736   69.682274   11.878612    0.113712   66.933110   66.260870
# std      5.726259   11.231071   17.563032    0.317994   12.238769   12.635527
# min     16.000000   40.000000    0.010000    0.000000   40.000000   41.000000
# 25%     21.000000   62.000000    0.900000    0.000000   58.000000   54.500000
# 50%     25.000000   71.000000    5.000000    0.000000   67.000000   65.000000
# 75%     29.500000   77.000000   16.000000    0.000000   75.000000   76.000000
# max     40.000000   94.000000  110.000000    1.000000   99.000000   97.000000
#
#        DOUBLE_PLACE    EDUCABLE  AGGRESSIVE
# count    299.000000  299.000000  299.000000
# mean       0.157191    0.351171    5.545151
# std        0.364591    0.478136    2.389954
# min        0.000000    0.000000    1.000000
# ...

# %%
dataFrame.isnull().sum()
# Out:
# AGE             0
# AVERAGE         0
# PLACE           0
# NATION          0
# PRICE           0
# STAR            0
# PASS            0
# PACE            0
# DOUBLE_PLACE    0
# EDUCABLE        0
# AGGRESSIVE      0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sbn.distplot(dataFrame["PRICE"])

# %%
sbn.countplot(dataFrame["NATION"])

# %%
sbn.countplot(dataFrame["STAR"])

# %%
dataFrame.corr() ["PRICE"].sort_values()
# Out:
# AGE            -0.064688
# AGGRESSIVE      0.050216
# EDUCABLE        0.156113
# DOUBLE_PLACE    0.322979
# STAR            0.520112
# AVERAGE         0.677809
# PACE            0.723301
# PASS            0.763668
# PRICE           1.000000
# Name: PRICE, dtype: float64

# %%
sbn.scatterplot(x= "PASS", y="PRICE", data= dataFrame)

# %%
dataFrame.sort_values("PRICE", ascending= False).head(20)
# Out:
#     AGE  AVERAGE PLACE NATION  PRICE  STAR  PASS  PACE  DOUBLE_PLACE  \
# 4    19       91    LW    GER  110.0     1    95    95             1
# 5    19       89    LW    SPA  110.0     1    92    93             1
# 3    20       89    CM    FRA   93.0     1    98    97             1
# 0    21       94    AM    FRA   88.0     1    90    96             1
# 13   21       87    CB    SPA   77.0     0    92    90             0
# 11   20       87    RB    HOL   72.0     0    90    96             0
# 32   27       83    RW    HOL   65.0     0    99    82             1
# 31   27       83    RW    HOL   65.0     0    99    82             1
# 1    35       93    RW    POR   65.0     1    97    97             1
# 2    27       90    RW    POR   65.0     1    91    97             0
# 6    23       88    LB    FRA   65.0     1    90    90             0
# 12   21       87    AM    ITA   55.0     0    92    77             1
# 14   22       87    CM    GER   52.0     1    94    92             0
# ...

# %%
dataFrame.sort_values("PRICE", ascending= True).head(20)
# Out:
#      AGE  AVERAGE PLACE NATION  PRICE  STAR  PASS  PACE  DOUBLE_PLACE  \
# 298   25       40    GK    SAN   0.01     0    40    50             0
# 233   17       60    AM    FRA   0.01     0    53    53             0
# 265   20       55    CB    AND   0.01     0    51    51             0
# 292   19       45    GK    SAN   0.01     0    50    50             0
# 288   22       46    GK    NOR   0.01     0    50    50             0
# 281   40       50    CB    AUS   0.01     0    50    50             0
# 282   22       49    CB    BUL   0.01     0    50    50             0
# 285   25       48    CF    LET   0.01     0    48    44             0
# 239   17       58    GK    TUR   0.02     0    53    53             0
# 275   30       52    CF    NOR   0.02     0    51    51             0
# 276   30       52    CF    NOR   0.02     0    51    51             0
# 279   30       50    CF    SCO   0.02     0    50    50             0
# ...

# %%
len(dataFrame)
# Out:
# 299

# %%
dataFrame.groupby("NATION").mean()["AVERAGE"]
siraliDF= dataFrame.sort_values("AVERAGE")

# %%
dataFrame.groupby("NATION").mean()["AGE"]
# Out:
# NATION
# ALB    19.500000
# AND    24.000000
# ARM    20.500000
# AUS    31.285714
# AZE    31.000000
# BEL    28.000000
# BOS    25.333333
# BUL    32.166667
# CRO    25.384615
# CYP    28.000000
# CZE    27.000000
# DAN    25.000000
# DEN    21.000000
# EST    29.000000
# FAR    21.333333
# FIN    26.000000
# FRA    25.076923
# GB     25.222222
# GEO    22.500000
# GER    29.500000
# GIB    23.833333
# GRE    32.750000
# HOL    25.285714
# HUN    18.000000
# ISL    24.000000
# ISR    30.500000
# ITA    26.500000
# LET    25.000000
# LIT    18.000000
# LUX    28.000000
# NIR    26.250000
# NOR    28.700000
# POL    23.000000
# POR    24.181818
# ROM    30.000000
# RUS    23.058824
# SAN    25.000000
# SCO    29.000000
# SIR    25.500000
# SPA    23.454545
# SW     27.000000
# SWE    22.000000
# SWI    23.000000
# TUR    23.148148
# UKR    22.818182
# Name: AGE, dtype: float64

# %%
dataFrame
# Out:
#      AGE  AVERAGE PLACE NATION   PRICE  STAR  PASS  PACE  DOUBLE_PLACE  \
# 0     21       94    AM    FRA   88.00     1    90    96             1
# 1     35       93    RW    POR   65.00     1    97    97             1
# 2     27       90    RW    POR   65.00     1    91    97             0
# 3     20       89    CM    FRA   93.00     1    98    97             1
# 4     19       91    LW    GER  110.00     1    95    95             1
# ..   ...      ...   ...    ...     ...   ...   ...   ...           ...
# 294   25       44    GK    GIB    0.05     0    44    51             0
# 295   25       43    GK    SAN    0.04     0    43    53             0
# 296   25       42    CB    LET    0.03     0    42    54             0
# 297   25       41    GK    GIB    0.02     0    41    41             0
# 298   25       40    GK    SAN    0.01     0    40    50             0
#
#      EDUCABLE  AGGRESSIVE
# 0           1           7
# 1           1           8
# 2           0           6
# ...

# %%
dataFrame = dataFrame.drop("NATION", axis=1)

# %%
dataFrame = dataFrame.drop("PLACE", axis=1)

# %%
y= dataFrame["PRICE"].values
x= dataFrame.drop("PRICE", axis=1).values

# %%
x
# Out:
# array([[21, 94,  1, ...,  1,  1,  7],
#        [35, 93,  1, ...,  1,  1,  8],
#        [27, 90,  1, ...,  0,  0,  6],
#        ...,
#        [25, 42,  0, ...,  0,  0,  9],
#        [25, 41,  0, ...,  0,  0,  9],
#        [25, 40,  0, ...,  0,  0, 10]], dtype=int64)

# %%
y
# Out:
# array([8.80e+01, 6.50e+01, 6.50e+01, 9.30e+01, 1.10e+02, 1.10e+02,
#        6.50e+01, 3.30e+01, 3.30e+01, 1.60e+01, 1.60e+01, 7.20e+01,
#        5.50e+01, 7.70e+01, 5.20e+01, 3.90e+01, 3.90e+01, 2.10e+01,
#        2.30e+01, 3.45e+01, 1.20e+01, 2.10e+01, 4.50e+01, 4.50e+01,
#        3.20e+01, 1.40e+01, 1.40e+01, 2.20e+01, 2.20e+01, 3.30e+01,
#        3.30e+01, 6.50e+01, 6.50e+01, 2.50e+01, 2.60e+01, 2.60e+01,
#        3.00e+01, 3.80e+01, 3.80e+01, 3.80e+01, 2.35e+01, 2.00e+01,
#        1.50e+01, 3.90e+01, 1.40e+01, 1.80e+01, 3.00e+01, 2.80e+01,
#        2.80e+01, 2.80e+01, 2.80e+01, 1.60e+01, 1.60e+01, 3.00e+01,
#        3.00e+01, 1.30e+01, 1.90e+01, 6.00e+00, 1.50e+01, 1.50e+01,
#        1.50e+01, 1.50e+01, 1.10e+01, 1.00e+01, 3.30e+01, 1.60e+01,
#        2.50e+01, 1.50e+01, 9.00e+00, 9.00e+00, 9.00e+00, 8.00e+00,
#        2.00e+01, 1.00e+01, 3.60e+01, 1.90e+01, 8.00e+00, 8.00e+00,
#        8.00e+00, 1.40e+01, 1.40e+01, 2.00e+00, 2.00e+00, 7.00e+00,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30, random_state=19)

# %%
len(x_train)
# Out:
# 209

# %%
len(x_test)
# Out:
# 90

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
dataFrame
# Out:
#      AGE  AVERAGE   PRICE  STAR  PASS  PACE  DOUBLE_PLACE  EDUCABLE  \
# 0     21       94   88.00     1    90    96             1         1
# 1     35       93   65.00     1    97    97             1         1
# 2     27       90   65.00     1    91    97             0         0
# 3     20       89   93.00     1    98    97             1         1
# 4     19       91  110.00     1    95    95             1         1
# ..   ...      ...     ...   ...   ...   ...           ...       ...
# 294   25       44    0.05     0    44    51             0         0
# 295   25       43    0.04     0    43    53             0         0
# 296   25       42    0.03     0    42    54             0         0
# 297   25       41    0.02     0    41    41             0         0
# 298   25       40    0.01     0    40    50             0         0
#
#      AGGRESSIVE
# 0             7
# 1             8
# 2             6
# 3             6
# 4             5
# ..          ...
# 294           5
# ...

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (209, 8)

# %%
model = Sequential()

model.add(Dense(6, activation="relu"))
model.add(Dense(6, activation="relu"))
model.add(Dense(6, activation="relu"))



model.add(Dense(1))
model.compile(optimizer = "adam", loss="mse")

# %%
model.fit(x=x_train, y=y_train, validation_data=(x_test,y_test), epochs= 300)
# Out:
# Train on 209 samples, validate on 90 samples
# Epoch 1/300
# 209/209 [==============================] - 2s 10ms/sample - loss: 467.2573 - val_loss: 417.3865
# Epoch 2/300
# 209/209 [==============================] - 0s 136us/sample - loss: 466.1323 - val_loss: 416.2020
# Epoch 3/300
# 209/209 [==============================] - 0s 194us/sample - loss: 464.9369 - val_loss: 415.1435
# Epoch 4/300
# 209/209 [==============================] - 0s 128us/sample - loss: 463.9526 - val_loss: 414.1119
# Epoch 5/300
# 209/209 [==============================] - 0s 138us/sample - loss: 462.8961 - val_loss: 413.1592
# Epoch 6/300
# 209/209 [==============================] - 0s 159us/sample - loss: 461.9415 - val_loss: 412.2318
# Epoch 7/300
# 209/209 [==============================] - 0s 123us/sample - loss: 461.0859 - val_loss: 411.3013
# Epoch 8/300
# 209/209 [==============================] - 0s 106us/sample - loss: 460.1272 - val_loss: 410.4461
# Epoch 9/300
# ...

# %%
kayipVerisi= pd.DataFrame(model.history.history)

# %%
kayipVerisi.head()
# Out:
#          loss    val_loss
# 0  467.257276  417.386455
# 1  466.132322  416.202035
# 2  464.936879  415.143489
# 3  463.952594  414.111878
# 4  462.896074  413.159247

# %%
kayipVerisi.plot()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
tahminDizisi = model.predict(x_test)

# %%
tahminDizisi
# Out:
# array([[44.935097  ],
#        [ 0.6268947 ],
#        [18.444532  ],
#        [16.025166  ],
#        [ 5.964795  ],
#        [ 0.63887423],
#        [ 8.272258  ],
#        [ 9.85451   ],
#        [ 7.2125807 ],
#        [16.572107  ],
#        [ 0.63181734],
#        [ 0.65724784],
#        [27.39643   ],
#        [ 5.856481  ],
#        [46.781475  ],
#        [ 0.6289662 ],
#        [ 3.0570054 ],
#        [31.570353  ],
#        [ 0.6015085 ],
#        [55.146786  ],
#        [ 3.5733738 ],
#        [ 3.7672827 ],
#        [ 0.6062712 ],
#        [ 0.61614764],
#        [32.854763  ],
#        [73.822464  ],
#        [39.394444  ],
#        [50.367443  ],
#        [ 0.6504099 ],
#        [43.038013  ],
#        [41.615696  ],
#        [ 0.9464415 ],
#        [ 5.1637363 ],
#        [ 2.380403  ],
#        [10.636519  ],
#        [16.025166  ],
#        [ 6.0716105 ],
#        [ 1.7322962 ],
#        [ 8.349992  ],
#        [10.281033  ],
#        [ 0.62043715],
# ...

# %%
mean_absolute_error(y_test,tahminDizisi)
# Out:
# 4.558443855444589

# %%
dataFrame.describe()
# Out:
#               AGE     AVERAGE       PRICE        STAR        PASS        PACE  \
# count  299.000000  299.000000  299.000000  299.000000  299.000000  299.000000
# mean    25.220736   69.682274   11.878612    0.113712   66.933110   66.260870
# std      5.726259   11.231071   17.563032    0.317994   12.238769   12.635527
# min     16.000000   40.000000    0.010000    0.000000   40.000000   41.000000
# 25%     21.000000   62.000000    0.900000    0.000000   58.000000   54.500000
# 50%     25.000000   71.000000    5.000000    0.000000   67.000000   65.000000
# 75%     29.500000   77.000000   16.000000    0.000000   75.000000   76.000000
# max     40.000000   94.000000  110.000000    1.000000   99.000000   97.000000
#
#        DOUBLE_PLACE    EDUCABLE  AGGRESSIVE
# count    299.000000  299.000000  299.000000
# mean       0.157191    0.351171    5.545151
# std        0.364591    0.478136    2.389954
# min        0.000000    0.000000    1.000000
# ...

# %%
plt.scatter(y_test, tahminDizisi)
plt.plot(y_test,y_test,"y-*")

# %%
dataFrame.head(2)
# Out:
#    AGE  AVERAGE  PRICE  STAR  PASS  PACE  DOUBLE_PLACE  EDUCABLE  AGGRESSIVE
# 0   21       94   88.0     1    90    96             1         1           7
# 1   35       93   65.0     1    97    97             1         1           8

# %%
dataFrame.corr() ["PRICE"].sort_values()
# Out:
# AGE            -0.064688
# AGGRESSIVE      0.050216
# EDUCABLE        0.156113
# DOUBLE_PLACE    0.322979
# STAR            0.520112
# AVERAGE         0.677809
# PACE            0.723301
# PASS            0.763668
# PRICE           1.000000
# Name: PRICE, dtype: float64

# %%
NewPlayer=[[18,70,1,70,70,0,0,1]]

# %%
NewPlayer=scaler.transform(NewPlayer)

# %%
model.predict(NewPlayer)
# Out:
# array([[20.903175]], dtype=float32)
